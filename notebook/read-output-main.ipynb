# %% [markdown]
# # Result of main experiment
# The best model is the 11.

# %%
FILE = 'params_main-no-augm-2.bin'

# %%
import pickle 
from matplotlib import pyplot as plt


with open("../output/{}".format(FILE), "rb") as file:
    v = pickle.load(file)
    #print(v)

# %%
# list all data in history
for el in v:
    #plt.figure(figsize=(50,50))
    history = el['hist']
    print(history.keys())
    # summarize history for accuracy
    """plt.plot(history['acc'])
    plt.plot(history['val_acc'])
    plt.title('model accuracy {} acc:{:2f}'.format(el['id'], el['loss_val']))
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    """
    # summarize history for loss
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('Model_{0[id]} - loss:{0[loss_val]:2f}, params {0[par]}'.format(el))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# ## Ccomparison with and without augmentation
# The fisrt graph is the best model of the above experiment and the second is the same model with image augmentation. We add 5 new image for every image.

# %%
#plt.figure(figsize=(50,50))
el = v[11]
history = el['hist']
# summarize history for loss
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model_{0[id]} - loss:{0[loss_val]:.2f}, params {0[par]}'.format(el))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


with open("../output/{}".format('params_best-augm-vgg16-2.bin'), "rb") as file:
    v2 = pickle.load(file)
    
el = v2[0]
history = el['hist']
# summarize history for loss
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model_{0[id]} - loss:{0[loss_val]:.2f}, params {0[par]}'.format(el))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
